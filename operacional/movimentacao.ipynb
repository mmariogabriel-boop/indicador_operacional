# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df = pd.read_excel('Movimentações (4).xlsx')
df
# Out:
#       Dt.Modificação Dt.Entrada SAP  \
# 0         2026-09-10     2026-09-11
# 1         2026-09-10     2026-09-11
# 2         2026-09-11     2026-09-11
# 3         2026-09-10     2026-09-11
# 4         2026-09-11     2026-09-11
# ...              ...            ...
# 44602     2025-12-30     2026-01-02
# 44603     2025-12-31     2026-01-02
# 44604     2025-12-31     2026-01-02
# 44605     2025-12-31     2026-01-02
# 44606     2025-12-31     2026-01-02
#
#                                             Beneficiário Dt.Assinatura  \
# 0              AGATHA PORTO VITAL DE MORAIS (0000106461)    2026-09-10
# 1              AGATHA PORTO VITAL DE MORAIS (0000106461)    2026-09-10
# 2                    CLAIVER DA SILVA PEDRA (0000114639)           NaT
# 3                     LUCAS SIMOES OLIVEIRA (0000089429)           NaT
# 4                     FELIP DA COSTA RANGEL (0000166852)           NaT
# ...                                                  ...           ...
# 44602                LAZARO DA SILVA PRATES (0000047334)           NaT
# 44603        SERGIO BIANCHI GIURIATO JUNIOR (0000104684)           NaT
# 44604        SERGIO BIANCHI GIURIATO JUNIOR (0000104684)           NaT
# 44605  THIAGO VASCONCELOS SANTOS DO NASCIMENTO (00000...           NaT
# 44606  THIAGO VASCONCELOS SANTOS DO NASCIMENTO (00000...           NaT
#
#       Dt.Retorno Pendencia                 Canal Recebimento Tp.Movimentação  \
# 0                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 1                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 2                      NaT      EMAIL (Digitado Manualmente)  EXC (Exclusão)
# 3                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 4                      NaT      EMAIL (Digitado Manualmente)  EXC (Exclusão)
# ...                    ...                               ...             ...
# 44602                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44603                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44604                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44605                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44606                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
#
#                                                Operadora  Id.Ct.Cliente  \
# 0                      1000151 (UNIMED VITORIA EST UNIF)           2044
# 1                    1000278 (UNIMED SAUDE E ODONTO S.A)           2044
# 2                      1000151 (UNIMED VITORIA EST UNIF)          13286
# 3                      1000151 (UNIMED VITORIA EST UNIF)          13440
# 4                      1000151 (UNIMED VITORIA EST UNIF)          28133
# ...                                                  ...            ...
# 44602                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44603  1000070 (AESP ODONTO ASSISTENCIA EM SAO PAULO DE)           7067
# 44604                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44605                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44606  1000070 (AESP ODONTO ASSISTENCIA EM SAO PAULO DE)           7067
#
#                                      Produto  ... Dt.Vigência  \
# 0      42 (4040 - Personal Ambulatorial Emp)  ...  2024-08-01
# 1                  124 (PLENO UNIMED ODONTO)  ...  2025-08-01
# 2      98 (7544 - Personal Ambulatorial Emp)  ...  2024-11-01
# 3      98 (7544 - Personal Ambulatorial Emp)  ...  2024-01-01
# 4      98 (7544 - Personal Ambulatorial Emp)  ...  2026-08-01
# ...                                      ...  ...         ...
# 44602  98 (7544 - Personal Ambulatorial Emp)  ...  2025-06-01
# 44603            137 (Executivo Odonto AESP)  ...  2024-12-01
# 44604  98 (7544 - Personal Ambulatorial Emp)  ...  2024-08-01
# 44605  98 (7544 - Personal Ambulatorial Emp)  ...  2023-09-01
# 44606            137 (Executivo Odonto AESP)  ...  2023-09-01
#
#            Dt.Cancelamento                Status Colaborador Resp.  \
# 0      2026-09-30 00:00:00  05 (Exclusão Futura)            JLUCIO
# 1      2026-09-30 00:00:00  05 (Exclusão Futura)            JLUCIO
# 2      2026-09-30 00:00:00  05 (Exclusão Futura)           EJUNIOR
# 3      2026-09-30 00:00:00  05 (Exclusão Futura)            JLUCIO
# 4      2026-09-30 00:00:00  05 (Exclusão Futura)           EJUNIOR
# ...                    ...                   ...               ...
# 44602  2025-12-29 00:00:00         10 (Excluído)         TMARCIANO
# 44603  2025-12-29 00:00:00         10 (Excluído)         TMARCIANO
# 44604  2025-12-29 00:00:00         10 (Excluído)         TMARCIANO
# 44605  2025-12-29 00:00:00         10 (Excluído)         TMARCIANO
# 44606  2025-12-29 00:00:00         10 (Excluído)         TMARCIANO
#
#         Dt.Criação / Venda Dt.Efetivação  \
# 0      2024-07-17 00:00:00    2026-05-21
# 1      2025-07-10 00:00:00    2026-05-21
# 2      2024-10-09 00:00:00    2026-07-14
# 3      2023-12-05 00:00:00    2026-08-12
# 4      2026-07-10 00:00:00    2026-07-14
# ...                    ...           ...
# 44602  2025-05-12 00:00:00    2026-06-08
# 44603  2024-11-08 00:00:00    2026-06-08
# 44604  2024-07-08 00:00:00    2026-06-08
# 44605  2023-08-01 00:00:00    2026-06-08
# 44606  2023-08-08 00:00:00    2026-06-08
#
#                                  Motivo Cancelamento  \
# 0       0000121585 (DESLIGAMENTO DA EMPRESA (RN279))
# 1       0000121586 (DESLIGAMENTO DA EMPRESA (RN279))
# 2       0000121588 (DESLIGAMENTO DA EMPRESA (RN279))
# 3       0000121589 (DESLIGAMENTO DA EMPRESA (RN279))
# 4       0000121590 (DESLIGAMENTO DA EMPRESA (RN279))
# ...                                              ...
# 44602  0000100563 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44603  0000100564 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44604  0000100565 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44605  0000100566 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44606  0000100566 (A PEDIDO DO BENEFICIÁRIO (RN561))
#
#                                                Corretora  \
# 0      0000000601 (ILHA AZUL SAUDE, SEGUROS, PREVIDEN...
# 1      0000000601 (ILHA AZUL SAUDE, SEGUROS, PREVIDEN...
# 2      0000043408 (SANTO'S GRAAL ADMINISTRACAO, CONSU...
# 3                            0000006871 (KSI BENEFÍCIOS)
# 4      0000006931 (PLATMEN VENDA DE PRODUTOS DE BENEF...
# ...                                                  ...
# 44602                        0000006882 (CLUBE 1 CENTRO)
# 44603                        0000006882 (CLUBE 1 CENTRO)
# 44604                        0000006882 (CLUBE 1 CENTRO)
# 44605                        0000006882 (CLUBE 1 CENTRO)
# 44606                        0000006882 (CLUBE 1 CENTRO)
#
#                                   Vendedor                          E-mail
# 0                                      NaN    material.republica@gmail.com
# 1                                      NaN    material.republica@gmail.com
# 2                                      NaN        rh@grassisolucoes.com.br
# 3         0000046253 (ATILA ROSA DE SALES)  dp2@lippausdistribuicao.com.br
# 4                                      NaN        rh@grassisolucoes.com.br
# ...                                    ...                             ...
# 44602  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44603  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44604  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44605  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44606  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
#
# [44607 rows x 23 columns]

# %%
# 1. Garantir que as colunas estão lidas estritamente como data/datetime
df['Dt.Modificação'] = pd.to_datetime(df['Dt.Modificação'], errors='coerce')
df['Dt.Entrada SAP'] = pd.to_datetime(df['Dt.Entrada SAP'], errors='coerce')

# 2. Função que calcula os dias úteis linha por linha, tratando os vazios
def calcular_dias_uteis(row):
    # Se qualquer uma das datas for nula (NaT/NaN), retorna NaN
    if pd.isnull(row['Dt.Modificação']) or pd.isnull(row['Dt.Entrada SAP']):
        return np.nan
    
    # Faz o cálculo seguro apenas com datas válidas
    return np.busday_count(
        str(row['Dt.Modificação'].date()), 
        str(row['Dt.Entrada SAP'].date())
    )

# 3. Aplica a função no DataFrame
df['dias_uteis'] = df.apply(calcular_dias_uteis, axis=1)

# %%
df['dias_uteis'] = df['dias_uteis'].astype('Int64')  # Converte para Int64, mantendo NaN como nulo

# %%
df
# Out:
#       Dt.Modificação Dt.Entrada SAP  \
# 0         2026-09-10     2026-09-11
# 1         2026-09-10     2026-09-11
# 2         2026-09-11     2026-09-11
# 3         2026-09-10     2026-09-11
# 4         2026-09-11     2026-09-11
# ...              ...            ...
# 44602     2025-12-30     2026-01-02
# 44603     2025-12-31     2026-01-02
# 44604     2025-12-31     2026-01-02
# 44605     2025-12-31     2026-01-02
# 44606     2025-12-31     2026-01-02
#
#                                             Beneficiário Dt.Assinatura  \
# 0              AGATHA PORTO VITAL DE MORAIS (0000106461)    2026-09-10
# 1              AGATHA PORTO VITAL DE MORAIS (0000106461)    2026-09-10
# 2                    CLAIVER DA SILVA PEDRA (0000114639)           NaT
# 3                     LUCAS SIMOES OLIVEIRA (0000089429)           NaT
# 4                     FELIP DA COSTA RANGEL (0000166852)           NaT
# ...                                                  ...           ...
# 44602                LAZARO DA SILVA PRATES (0000047334)           NaT
# 44603        SERGIO BIANCHI GIURIATO JUNIOR (0000104684)           NaT
# 44604        SERGIO BIANCHI GIURIATO JUNIOR (0000104684)           NaT
# 44605  THIAGO VASCONCELOS SANTOS DO NASCIMENTO (00000...           NaT
# 44606  THIAGO VASCONCELOS SANTOS DO NASCIMENTO (00000...           NaT
#
#       Dt.Retorno Pendencia                 Canal Recebimento Tp.Movimentação  \
# 0                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 1                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 2                      NaT      EMAIL (Digitado Manualmente)  EXC (Exclusão)
# 3                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 4                      NaT      EMAIL (Digitado Manualmente)  EXC (Exclusão)
# ...                    ...                               ...             ...
# 44602                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44603                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44604                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44605                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44606                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
#
#                                                Operadora  Id.Ct.Cliente  \
# 0                      1000151 (UNIMED VITORIA EST UNIF)           2044
# 1                    1000278 (UNIMED SAUDE E ODONTO S.A)           2044
# 2                      1000151 (UNIMED VITORIA EST UNIF)          13286
# 3                      1000151 (UNIMED VITORIA EST UNIF)          13440
# 4                      1000151 (UNIMED VITORIA EST UNIF)          28133
# ...                                                  ...            ...
# 44602                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44603  1000070 (AESP ODONTO ASSISTENCIA EM SAO PAULO DE)           7067
# 44604                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44605                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44606  1000070 (AESP ODONTO ASSISTENCIA EM SAO PAULO DE)           7067
#
#                                      Produto  ...      Dt.Cancelamento  \
# 0      42 (4040 - Personal Ambulatorial Emp)  ...  2026-09-30 00:00:00
# 1                  124 (PLENO UNIMED ODONTO)  ...  2026-09-30 00:00:00
# 2      98 (7544 - Personal Ambulatorial Emp)  ...  2026-09-30 00:00:00
# 3      98 (7544 - Personal Ambulatorial Emp)  ...  2026-09-30 00:00:00
# 4      98 (7544 - Personal Ambulatorial Emp)  ...  2026-09-30 00:00:00
# ...                                      ...  ...                  ...
# 44602  98 (7544 - Personal Ambulatorial Emp)  ...  2025-12-29 00:00:00
# 44603            137 (Executivo Odonto AESP)  ...  2025-12-29 00:00:00
# 44604  98 (7544 - Personal Ambulatorial Emp)  ...  2025-12-29 00:00:00
# 44605  98 (7544 - Personal Ambulatorial Emp)  ...  2025-12-29 00:00:00
# 44606            137 (Executivo Odonto AESP)  ...  2025-12-29 00:00:00
#
#                      Status Colaborador Resp.   Dt.Criação / Venda  \
# 0      05 (Exclusão Futura)            JLUCIO  2024-07-17 00:00:00
# 1      05 (Exclusão Futura)            JLUCIO  2025-07-10 00:00:00
# 2      05 (Exclusão Futura)           EJUNIOR  2024-10-09 00:00:00
# 3      05 (Exclusão Futura)            JLUCIO  2023-12-05 00:00:00
# 4      05 (Exclusão Futura)           EJUNIOR  2026-07-10 00:00:00
# ...                     ...               ...                  ...
# 44602         10 (Excluído)         TMARCIANO  2025-05-12 00:00:00
# 44603         10 (Excluído)         TMARCIANO  2024-11-08 00:00:00
# 44604         10 (Excluído)         TMARCIANO  2024-07-08 00:00:00
# 44605         10 (Excluído)         TMARCIANO  2023-08-01 00:00:00
# 44606         10 (Excluído)         TMARCIANO  2023-08-08 00:00:00
#
#       Dt.Efetivação                            Motivo Cancelamento  \
# 0        2026-05-21   0000121585 (DESLIGAMENTO DA EMPRESA (RN279))
# 1        2026-05-21   0000121586 (DESLIGAMENTO DA EMPRESA (RN279))
# 2        2026-07-14   0000121588 (DESLIGAMENTO DA EMPRESA (RN279))
# 3        2026-08-12   0000121589 (DESLIGAMENTO DA EMPRESA (RN279))
# 4        2026-07-14   0000121590 (DESLIGAMENTO DA EMPRESA (RN279))
# ...             ...                                            ...
# 44602    2026-06-08  0000100563 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44603    2026-06-08  0000100564 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44604    2026-06-08  0000100565 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44605    2026-06-08  0000100566 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44606    2026-06-08  0000100566 (A PEDIDO DO BENEFICIÁRIO (RN561))
#
#                                                Corretora  \
# 0      0000000601 (ILHA AZUL SAUDE, SEGUROS, PREVIDEN...
# 1      0000000601 (ILHA AZUL SAUDE, SEGUROS, PREVIDEN...
# 2      0000043408 (SANTO'S GRAAL ADMINISTRACAO, CONSU...
# 3                            0000006871 (KSI BENEFÍCIOS)
# 4      0000006931 (PLATMEN VENDA DE PRODUTOS DE BENEF...
# ...                                                  ...
# 44602                        0000006882 (CLUBE 1 CENTRO)
# 44603                        0000006882 (CLUBE 1 CENTRO)
# 44604                        0000006882 (CLUBE 1 CENTRO)
# 44605                        0000006882 (CLUBE 1 CENTRO)
# 44606                        0000006882 (CLUBE 1 CENTRO)
#
#                                   Vendedor                          E-mail  \
# 0                                      NaN    material.republica@gmail.com
# 1                                      NaN    material.republica@gmail.com
# 2                                      NaN        rh@grassisolucoes.com.br
# 3         0000046253 (ATILA ROSA DE SALES)  dp2@lippausdistribuicao.com.br
# 4                                      NaN        rh@grassisolucoes.com.br
# ...                                    ...                             ...
# 44602  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44603  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44604  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44605  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44606  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
#
#       dias_uteis
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0
# ...          ...
# 44602          3
# 44603          2
# 44604          2
# 44605          2
# 44606          2
#
# [44607 rows x 24 columns]

# %%
condicoes = [df['dias_uteis']<=4, df['dias_uteis']>4]
resultado = ['Dentro do prazo', 'Fora do prazo']

df['Indicador'] = np.select(
    [condicao.fillna(False).to_numpy(dtype=bool) for condicao in condicoes],
    resultado,
    default='Verificar'
)

# %%
df['Competencia'] = df['Dt.Modificação'].dt.to_period('M').astype(str)

# %%
df
# Out:
#       Dt.Modificação Dt.Entrada SAP  \
# 0         2026-09-10     2026-09-11
# 1         2026-09-10     2026-09-11
# 2         2026-09-11     2026-09-11
# 3         2026-09-10     2026-09-11
# 4         2026-09-11     2026-09-11
# ...              ...            ...
# 44602     2025-12-30     2026-01-02
# 44603     2025-12-31     2026-01-02
# 44604     2025-12-31     2026-01-02
# 44605     2025-12-31     2026-01-02
# 44606     2025-12-31     2026-01-02
#
#                                             Beneficiário Dt.Assinatura  \
# 0              AGATHA PORTO VITAL DE MORAIS (0000106461)    2026-09-10
# 1              AGATHA PORTO VITAL DE MORAIS (0000106461)    2026-09-10
# 2                    CLAIVER DA SILVA PEDRA (0000114639)           NaT
# 3                     LUCAS SIMOES OLIVEIRA (0000089429)           NaT
# 4                     FELIP DA COSTA RANGEL (0000166852)           NaT
# ...                                                  ...           ...
# 44602                LAZARO DA SILVA PRATES (0000047334)           NaT
# 44603        SERGIO BIANCHI GIURIATO JUNIOR (0000104684)           NaT
# 44604        SERGIO BIANCHI GIURIATO JUNIOR (0000104684)           NaT
# 44605  THIAGO VASCONCELOS SANTOS DO NASCIMENTO (00000...           NaT
# 44606  THIAGO VASCONCELOS SANTOS DO NASCIMENTO (00000...           NaT
#
#       Dt.Retorno Pendencia                 Canal Recebimento Tp.Movimentação  \
# 0                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 1                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 2                      NaT      EMAIL (Digitado Manualmente)  EXC (Exclusão)
# 3                      NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 4                      NaT      EMAIL (Digitado Manualmente)  EXC (Exclusão)
# ...                    ...                               ...             ...
# 44602                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44603                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44604                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44605                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
# 44606                  NaT  PORTAL (Portal de Movimentações)  EXC (Exclusão)
#
#                                                Operadora  Id.Ct.Cliente  \
# 0                      1000151 (UNIMED VITORIA EST UNIF)           2044
# 1                    1000278 (UNIMED SAUDE E ODONTO S.A)           2044
# 2                      1000151 (UNIMED VITORIA EST UNIF)          13286
# 3                      1000151 (UNIMED VITORIA EST UNIF)          13440
# 4                      1000151 (UNIMED VITORIA EST UNIF)          28133
# ...                                                  ...            ...
# 44602                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44603  1000070 (AESP ODONTO ASSISTENCIA EM SAO PAULO DE)           7067
# 44604                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44605                  1000151 (UNIMED VITORIA EST UNIF)           7067
# 44606  1000070 (AESP ODONTO ASSISTENCIA EM SAO PAULO DE)           7067
#
#                                      Produto  ... Colaborador Resp.  \
# 0      42 (4040 - Personal Ambulatorial Emp)  ...            JLUCIO
# 1                  124 (PLENO UNIMED ODONTO)  ...            JLUCIO
# 2      98 (7544 - Personal Ambulatorial Emp)  ...           EJUNIOR
# 3      98 (7544 - Personal Ambulatorial Emp)  ...            JLUCIO
# 4      98 (7544 - Personal Ambulatorial Emp)  ...           EJUNIOR
# ...                                      ...  ...               ...
# 44602  98 (7544 - Personal Ambulatorial Emp)  ...         TMARCIANO
# 44603            137 (Executivo Odonto AESP)  ...         TMARCIANO
# 44604  98 (7544 - Personal Ambulatorial Emp)  ...         TMARCIANO
# 44605  98 (7544 - Personal Ambulatorial Emp)  ...         TMARCIANO
# 44606            137 (Executivo Odonto AESP)  ...         TMARCIANO
#
#         Dt.Criação / Venda Dt.Efetivação  \
# 0      2024-07-17 00:00:00    2026-05-21
# 1      2025-07-10 00:00:00    2026-05-21
# 2      2024-10-09 00:00:00    2026-07-14
# 3      2023-12-05 00:00:00    2026-08-12
# 4      2026-07-10 00:00:00    2026-07-14
# ...                    ...           ...
# 44602  2025-05-12 00:00:00    2026-06-08
# 44603  2024-11-08 00:00:00    2026-06-08
# 44604  2024-07-08 00:00:00    2026-06-08
# 44605  2023-08-01 00:00:00    2026-06-08
# 44606  2023-08-08 00:00:00    2026-06-08
#
#                                  Motivo Cancelamento  \
# 0       0000121585 (DESLIGAMENTO DA EMPRESA (RN279))
# 1       0000121586 (DESLIGAMENTO DA EMPRESA (RN279))
# 2       0000121588 (DESLIGAMENTO DA EMPRESA (RN279))
# 3       0000121589 (DESLIGAMENTO DA EMPRESA (RN279))
# 4       0000121590 (DESLIGAMENTO DA EMPRESA (RN279))
# ...                                              ...
# 44602  0000100563 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44603  0000100564 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44604  0000100565 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44605  0000100566 (A PEDIDO DO BENEFICIÁRIO (RN561))
# 44606  0000100566 (A PEDIDO DO BENEFICIÁRIO (RN561))
#
#                                                Corretora  \
# 0      0000000601 (ILHA AZUL SAUDE, SEGUROS, PREVIDEN...
# 1      0000000601 (ILHA AZUL SAUDE, SEGUROS, PREVIDEN...
# 2      0000043408 (SANTO'S GRAAL ADMINISTRACAO, CONSU...
# 3                            0000006871 (KSI BENEFÍCIOS)
# 4      0000006931 (PLATMEN VENDA DE PRODUTOS DE BENEF...
# ...                                                  ...
# 44602                        0000006882 (CLUBE 1 CENTRO)
# 44603                        0000006882 (CLUBE 1 CENTRO)
# 44604                        0000006882 (CLUBE 1 CENTRO)
# 44605                        0000006882 (CLUBE 1 CENTRO)
# 44606                        0000006882 (CLUBE 1 CENTRO)
#
#                                   Vendedor                          E-mail  \
# 0                                      NaN    material.republica@gmail.com
# 1                                      NaN    material.republica@gmail.com
# 2                                      NaN        rh@grassisolucoes.com.br
# 3         0000046253 (ATILA ROSA DE SALES)  dp2@lippausdistribuicao.com.br
# 4                                      NaN        rh@grassisolucoes.com.br
# ...                                    ...                             ...
# 44602  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44603  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44604  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44605  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
# 44606  0000046171 (GLEIDSON DIAS DA SILVA)              sorvetudo@live.com
#
#       dias_uteis        Indicador Competencia
# 0              1  Dentro do prazo     2026-09
# 1              1  Dentro do prazo     2026-09
# 2              0  Dentro do prazo     2026-09
# 3              1  Dentro do prazo     2026-09
# 4              0  Dentro do prazo     2026-09
# ...          ...              ...         ...
# 44602          3  Dentro do prazo     2025-12
# 44603          2  Dentro do prazo     2025-12
# 44604          2  Dentro do prazo     2025-12
# 44605          2  Dentro do prazo     2025-12
# 44606          2  Dentro do prazo     2025-12
#
# [44607 rows x 26 columns]

# %%
dentro_do_prazo = df[df['Indicador']=='Dentro do prazo']
fora_do_prazo = df[df['Indicador']=='Fora do prazo']

# %%
dentro_do_prazo = dentro_do_prazo.groupby('Competencia').size().reset_index(name='Quantidade')
fora_do_prazo = fora_do_prazo.groupby('Competencia').size().reset_index(name='Quantidade')

# %%
indicador = pd.merge(dentro_do_prazo, fora_do_prazo, on='Competencia', how='outer', suffixes=('_Dentro', '_Fora')).fillna(0)
indicador['total'] = indicador['Quantidade_Dentro'] + indicador['Quantidade_Fora']

# %%
import matplotlib.pyplot as plt
import numpy as np

comp = indicador['Competencia'].astype(str)
dentro = indicador['Quantidade_Dentro'].astype(int)
fora = indicador['Quantidade_Fora'].astype(int)

width = 0.60

fig, ax = plt.subplots(figsize=(12, 6))

# Dentro do prazo
barra_dentro = ax.bar(
    comp,
    dentro,
    width,
    label='Dentro do prazo',
    color='green'
)

# Fora do prazo
barra_fora = ax.bar(
    comp,
    fora,
    width,
    bottom=dentro,
    label='Fora do prazo',
    color='red'
)

# Rótulos da parte verde
ax.bar_label(
    barra_dentro,
    labels=[f'{valor}' if valor > 0 else '' for valor in dentro],
    label_type='center',
    color='white',
    fontsize=10,
    fontweight='bold'
)

# Rótulos da parte vermelha
ax.bar_label(
    barra_fora,
    labels=[f'{valor}' if valor > 0 else '' for valor in fora],
    label_type='center',
    color='white',
    fontsize=10,
    fontweight='bold'
)

ax.set_title(
    'Indicador de Movimentações por Competência',
    fontsize=14,
    fontweight='bold'
)

ax.set_xlabel('Competência')
ax.set_ylabel('Quantidade')

ax.legend()

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
